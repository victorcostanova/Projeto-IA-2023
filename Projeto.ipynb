# %% [markdown]
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg"  width=300, align="right">
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # ***YOLOv8 para detecção e classificação de frutas.***
# ---

# %% [markdown]
# *Siga esse template para entrega do seu artigo/projeto. O código deste notebook precisa ser 100% executável.*
#
# Neste projeto você vai explorar algumas tecnologias que são o estado da arte da IA e do Aprendizado de Máquina. Seu grupo deve ter escolhido uma dentre as seguintes tecnologias ou conceitos para explorar:
#
# * **Tools**
#   * BERT, tradução ou sumarização de texto
#   * Yolo e OpenCV, para detecção de objetos em Imagens
#   * Yolo e OpenCV, para detecção de objetos Vídeos
#
# * **Conceitos**
#   * Generative Adversarial Neural Networks
#   * Transformers (outras aplicações que não NLP, como o BERT)
#   * Sentiment Analysis (em Português)
#   * Anomaly Detection
#
# Vocês devem produzir um *artigo*, a exemplo de artigos do *Medium* ou outros canais semelhantes, para que seu grupo ou leitores do artigo tenham aqui um ponto de partida para uso da tecnologia/conceito escolhido.
#
# <br>
#
# <br>
#
# **ATENÇÃO**
#
# * Podem haver apenas 3 trabalhos para um mesmo tema.
# * Cadastre o nome completo de 1 aluno do grupo para selecionar o tema aqui [7G](https://docs.google.com/spreadsheets/d/1P4Pw7dXs3d_QGKiT6AmmZo3i4wOvXHhuF8cYWSSidGE/edit?usp=sharing) ou [7N](https://docs.google.com/spreadsheets/d/1QSstslQFsP2ecMlrYbwfQXcP-3stcdYJmb22zvu8ASw/edit?usp=sharing). Respeite a escolha dos Colegas!

# %%
#@title **Identificação do Grupo**

#@markdown Integrantes do Grupo, nome completo em orgem alfabética (*informe \<TIA\>,\<nome\>*)
Aluno1 = '32087411, Joao Pedro Bianchini Ramos' #@param {type:"string"}
Aluno2 = '32058179, Lucas Souza Silva' #@param {type:"string"}
Aluno3 = '32052960, Victor Costa Nova Alexandre' #@param {type:"string"}
Aluno4 = '32013639, Vinicius Rodrigues Figueira de Faria' #@param {type:"string"}
Aluno5 = "41994647, Wellerson Rodrigues Alves'" #@param {type:"string"}

# %% [markdown]
# # **Resumo (*Abstract*)**
#
# A ideia é criar uma base de dados com imagens de bananas e utilizar o YOLOv8 em conjunto com o framework Darknet. O objetivo é ensinar a rede neural a identificar e classificar bananas com base em sua aparência física, como manchas, formato e coloração, distinguindo entre bananas prontas para consumo e bananas imaturas. Utilizaremos o YOLOv8 para detectar os objetos na imagens escolhidas e, em seguida, utilizaremos o modelo de previsão das classes para identificar e localizar corretamente os objetos detectados.

# %% [markdown]
# # **Referencial Teórico**
# ##*YOLOv8*
# O algoritmo para a detecção das frutas que será utilizado é o YOLOv8, ele é o mais recentes da família YOLO, desenvolvido pela Ultralytics, YOLOv8 foi criado pra ser rápido, preciso e facil de manejar, esse algoritmo é muito utilizado em sistemas de monitoramento em tempo real, como câmeras de CFTV e veículos autônomos.
#
# ![image.png](data:image/png;base64,...)
#
# O YOLO funciona inicialmente dividindo a imagem em um grid de células. Cada célula é responsável por prever um conjunto de caixas delimitadoras que podem conter objetos. Em seguida, são realizadas a regressão das coordenadas das caixas, atribuição de pontuações e classificação dos objetos contidos nessas caixas.
#
# ## Roboflow
# É uma plataforma de computação visual que permite ao usuário construir rapidamente modelos mais precisos a partir de coleções de dados, pré-processamento e técnicas de treinamento de modelo. Ela permite que o usuário faça upload imagens e vídeos personalizados, realize anotações nessas mídias para rotular os objetos de interesse, modifique a orientação e o tamanho da imagem e treine os modelos de machine learning com mais facilidade.
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# #Plataforma
# Dataset no Roboflow
# <div align="center">
#   <img
#     width="640"
#     src="https://i.imgur.com/UwJENdM.png"
#   >
# </div>
#
#
# #Imagens
# Processor de criação de tags no roboflow:
# <div align="center">
#   <img
#     width="640"
#     src="https://i.imgur.com/hAV8x5d.png"
#   >
# </div>
#
# A plataforma também permite a geração automática de código para integração em fluxos de trabalho e a conversão de diferentes formatos de anotação.

# %% [markdown]
# # **Conceitos Chave**
# ## 1. *YOLOv8*
# O YOLO é um algoritmo de detecção de objetos que divide a imagem em uma grade de células e atribui a cada célula a responsabilidade de prever caixas delimitadoras de objetos. Utilizando em conjunto o Darknet para uma implementacao mais otimizada e eficiente do YOLO
#
# ## 2. *Roboflow*
# É uma plataforma de computação visual que permite ao usuário construir rapidamente modelos mais precisos a partir de coleções de dados, pré-processamento e técnicas de treinamento de modelo. Ela permite que o usuário faça upload de conjuntos de dados personalizados, realize anotações, modifique a orientação e o tamanho da imagem, sendo também utilizada para treinar modelos.
#
# ## 3. *Deteccao de Objetos*
# Está relacionada com computacao visual, processamento de imagens e deep learning, lidando com a deteccao de objetos em imagens ou vídeos
#
# ## 4. *Redes Convolucionais*
# Tambem conhecidas como redes neurais, sao algoritmos de Deep Learning usados no processamento de imagens, com o objetivo de detectar informacoes e caracteristicas importantes das imagens, detectando padroes, como bordas e texturas.

# %% [markdown]
# # **Exemplo de Aplicação**
# O problema a ser resolvido nesse projeto é a deteccao, classificacao e diferenciacao do estado de bananas através da computacao visual, utilizando o algoritmo YOLOv8, vamos detectar se uma banana está madura, verde ou amarela.

# %% [markdown]
# # **Exemplo de Código**
#
# Coloque aqui o código de solução. Você deve explicar em linhas gerais o código. Para isso você pode quebrar o código em algumas partes e incluir células de texto explicativos. Não empregue para isso comentários no corpo do código.
#
# Tente empregar exemplos que não sejam muito complexos e que busquem dar a você ou ao leitor um ponto de partida para o uso da tecnologia/conceito explorado.

# %% [markdown]
# ## ⚠ IMPORTANTE ⚠
# Verifique se o notebook no Google Colab esta usando a GPU como acelerador de Hardware, você pode verificar isso em *Editar -> Configurações do notebook -> Acelerador de Hardware*

# %%
# !nvidia-smi
# Out:
# Sun Jun  4 17:43:10 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Instalacao
# Instalacao do roboflow e YOLOv8 pelo ultralytics

# %%
# !pip install roboflow
# !pip install ultralytics

import os
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %% [markdown]
# ## Yolo e Roboflow
# Importar o YOLOv8 e o Roboflow para o ambiente do Google Colab

# %%
from ultralytics import YOLO
from roboflow import Roboflow
from IPython import display
from IPython.display import display, Image

# %% [markdown]
# ## Criação do dataset
# Após criar o conjunto de dados dentro da plataforma Roboflow, é necessário importá-lo para este ambiente utilizando a chave da API, o nome do espaço de trabalho e o nome do projeto que foram criados, o nosso modelo se encontra em: https://universe.roboflow.com/felipe-qf56r/bananinha-lz0ec

# %%
HOME = os.getcwd()

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
rf = Roboflow(api_key="c4ioPjniKjXMgMqQ0KaV")
project = rf.workspace("felipe-qf56r").project("bananinha-lz0ec")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.112, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Bananinha-2 in yolov8:: 100%|██████████| 176/176 [00:00<00:00, 1386.64it/s]

# %% [markdown]
# ##Treinamento customizado
# Nesse trecho de código é realizado o treinamento do modelo personalizado no roboflow.

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 31.2MB/s]
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Verificar
# Verificar os arquivos do treinamento e a matriz de confusao.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					   R_curve.png
# confusion_matrix_normalized.png			   results.csv
# confusion_matrix.png				   results.png
# events.out.tfevents.1685900633.a0fcd11b8060.625.0  train_batch0.jpg
# F1_curve.png					   train_batch1.jpg
# labels_correlogram.jpg				   train_batch2.jpg
# labels.jpg					   val_batch0_labels.jpg
# P_curve.png					   val_batch0_pred.jpg
# PR_curve.png					   weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %% [markdown]
# ## Treinamento
# Demonstracao de como o treinamento foi feito, mostrando as frutas sendo detectadas.

# %%
Image(filename=f'{HOME}/runs/detect/train/train_batch1.jpg', width=600)

# %% [markdown]
# ## Dados do treinamento
# Valores do treinamento

# %%
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %% [markdown]
# ## Resultado Final
# Demonstracao da deteccao das frutas após o treinamento do modelo.

# %%
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
#@title
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
#@title ## Agora teste você mesmo { run: "auto" }

#@markdown ---
#@markdown #### Escolha o formato da imagem:
Fonte_da_imagem = '' #@param ["","Upload", "Webcam", "Link"]
#@markdown ---

if Fonte_da_imagem == '':
  print("Selecione uma das opções acima")
if Fonte_da_imagem == "Upload":
  from google.colab import files
  img = files.upload()
  PATH_IMG = list(img.keys())[0]
#elif Fonte_da_imagem == "Webcam":
  #img = take_photo()
  #PATH_IMG = img
#elif Fonte_da_imagem == "Link":
  #pass

def detect():
  print(PATH_IMG)
  # !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={PATH_IMG} save=True
  Image(filename=f'{HOME}/runs/detect/predict/{PATH_IMG}', width=600)
  # %rm -r {HOME}/runs/detect/predict/
# Out:
#      <input type="file" id="files-f35dafce-2248-4864-bd18-fcb3459930eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f35dafce-2248-4864-bd18-fcb3459930eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Ideias de Projeto de Aplicação**
#
# Considerando o caso de uma pessoa que tenha dificuldade para enxergar, essa aplicação poderia ser utilizada em conjunto com um óculos inteligente. Quando o deficiente visual olhasse para a fruta, no caso a banana, a aplicação retornaria, de forma sonora, o estado atual da banana. Esse projeto pode ser atualizado para incluir informações de mais frutas e se tornar mais completo.

# %% [markdown]
# # **Referências**
#
# Simple Approach to Create Deep Learning Model which will be able to Recognize Fresh Vs Rotten. Medium, 2022. Disponível em: https://python.plainenglish.io/simple-approach-to-create-deep-learning-model-which-will-be-able-to-recognize-fresh-vs-rotten-eeb7bca00023.
#
# Kanupuru, Priyanka & Reddy, N.V. (2022). A Deep Learning Approach to Detect the Spoiled Fruits. WSEAS TRANSACTIONS ON COMPUTER RESEARCH. 10. 74-87. 10.37394/232018.2022.10.10.
#
# Lee S-H. A Study on Fruit Quality Identification Using YOLO V2 Algorithm. International Journal of Advanced Culture Technology [Internet]. 2021 Mar 31;9(1):190–5. Disponível em: https://doi.org/10.17703/IJACT.2021.9.1.190.
#
# EricKiennemann, Fruit-Detection-with-Yolov4. Disponível em:
# https://github.com/EricKiennemann/Fruit-Detection-with-Yolov4. Acesso em 4 de Junho de 2023.
#
# The AI Guy, YOLOv4 Object Detection on Webcam In Google Colab. Google Colab. Disponível em: https://colab.research.google.com/drive/1xdjyBiY75MAVRSjgmiqI7pbRLn58VrbE?usp=sharing#scrollTo=M_btEC1N-YkS. Acesso em 3 de Junho de 2023.
#
# The AI Guy, Real-time YOLOv4 Object Detection on Webcam in Google Colab | Images and Video, 31 de dez. de 2020. Disponível em: https://www.youtube.com/watch?v=ebAykr9YZ30. Acesso em 3 de Junho de 2023.
#
# Theophilus, S. Roboflow: Converting Annotations for Object Detection, Medium. Disponível em: https://medium.com/analytics-vidhya/converting-annotations-for-object-detection-using-roboflow-5d0760bd5871. Acesso em 4 de Junho de 2023.

# %% [markdown]
# # **Vídeo**
#
# Produza um vídeo explicativo apresentando o seu trabalho. [Aqui](https://github.com/Rogerio-mack/IA_2023S1/raw/main/Exemplo_Video.mp4) um exemplo de vídeo curto de apresentação, embora trate de um projeto mais simples envolvendo apenas aplicação de ML tradicional.

# %% [markdown]
# # **GitHub e Publicação (opcional)**
#
# Se bem avaliado, e tiver interesse, podemos publicar seu texto no Medium.

# %% [markdown]
# # **Conclusão**
#
# São imensas as possibilidades de aplicação de projetos de computação visual. A detecção de objetos pode ser utilizada em diversos contextos, como em carros autônomos ou em drones. Nosso projeto atingiu as expectativas, mas acreditamos que seria interessante adicionar a possibilidade de detecção de objetos em tempo real, utilizando uma webcam, por exemplo. Além disso, a adoção de outras frutas no modelo de treinamento tornaria o projeto mais completo.

# %% [markdown]
# ---

# %%
#@title **Avaliação**
Referencial_Teorico = 9 #@param {type:"slider", min:0, max:10, step:1}

Conceitos_Chave = 9 #@param {type:"slider", min:0, max:10, step:1}

Exemplo_Aplicacao = 6 #@param {type:"slider", min:0, max:10, step:1}

Ideia_Projeto = 7 #@param {type:"slider", min:0, max:10, step:1}

Conclusao = 7 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = Referencial_Teorico + Conceitos_Chave + 2*Exemplo_Aplicacao + 2*Ideia_Projeto + Conclusao

nota = nota / 7

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_tia = []
lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_tia.append(lista[0]); lista_nome.append(lista[1].upper())")

alunos['tia'] = lista_tia
alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 7.3
#         tia                                   nome  nota
# 0  32087411             JOAO PEDRO BIANCHINI RAMOS   7.3
# 1  32058179                      LUCAS SOUZA SILVA   7.3
# 2  32052960            VICTOR COSTA NOVA ALEXANDRE   7.3
# 3  32013639   VINICIUS RODRIGUES FIGUEIRA DE FARIA   7.3
# 4  41994647             WELLERSON RODRIGUES ALVES'   7.3
